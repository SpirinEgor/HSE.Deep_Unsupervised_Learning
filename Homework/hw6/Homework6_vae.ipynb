# %% [markdown]
# <a href="https://colab.research.google.com/github/SpirinEgor/HSE.Deep_Unsupervised_Learning/blob/hw6/Homework/hw6/Homework6_vae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi
# Out:
# Tue Dec  7 23:47:42 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    72W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
! if [ -d HSE.Deep_Unsupervised_Learning ]; then rm -Rf HSE.Deep_Unsupervised_Learning; fi
! git clone https://github.com/SpirinEgor/HSE.Deep_Unsupervised_Learning.git
# %cd HSE.Deep_Unsupervised_Learning
! git checkout hw6
# Out:
# Cloning into 'HSE.Deep_Unsupervised_Learning'...
# remote: Enumerating objects: 596, done.
# remote: Counting objects: 100% (596/596), done.
# remote: Compressing objects: 100% (365/365), done.
# remote: Total 596 (delta 286), reused 457 (delta 191), pack-reused 0
# Receiving objects: 100% (596/596), 38.22 MiB | 28.32 MiB/s, done.
# Resolving deltas: 100% (286/286), done.
# /content/HSE.Deep_Unsupervised_Learning
# Branch 'hw6' set up to track remote branch 'hw6' from 'origin'.
# Switched to a new branch 'hw6'

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: scipy~=1.7.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.7.3)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.10.0+cu111)
# Requirement already satisfied: numpy~=1.21.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.21.4)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.11.1+cu111)
# Requirement already satisfied: pillow~=8.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (8.4.0)
# Requirement already satisfied: tqdm~=4.62.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (4.62.3)
# Requirement already satisfied: torchdiffeq~=0.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (4.28.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (6.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib~=3.5.0->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9.0->-r requirements.txt (line 3)) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib~=3.5.0->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib~=3.5.0->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib~=3.5.0->-r requirements.txt (line 1)) (57.4.0)

# %%
! git pull
# Out:
# Already up to date.

# %%
# %%capture
! mkdir -p Homework/hw6/data
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF" -O Homework/hw6/data/data.zip && rm -rf /tmp/cookies.txt
! unzip -qq Homework/hw6/data/data.zip -d Homework/hw6/data

# %%
# %cd ../..
# Out:
# /Users/Egor.Spirin/HSE/HSE.Deep_Unsupervised_Learning

# %%
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Dataset

from utils.hw6_utils import *
from vae import VAETrainer, VqVaeTrainer
from pixel_cnn import PixelCNNVae, train_pixel_cnn

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
plt.rcParams["axes.labelsize"] = 25.0
plt.rcParams["xtick.labelsize"] = 20.0
plt.rcParams["ytick.labelsize"] = 20.0
plt.rcParams["legend.fontsize"] = 18.0

plt.rcParams["figure.figsize"] = [8.0, 6.0]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Question 1: VAEs on Images
# In this question, you will train VAE model on image datasets. Execute the cell below to visualize the two datasets (colored shapes, and [SVHN](http://ufldl.stanford.edu/housenumbers/)).

# %%
visualize_svhn()
visualize_cifar10()

# %% [markdown]
# ## VAE with AF Prior
# In this part, implement a VAE with an Autoregressive Flow prior ([VLAE](https://arxiv.org/abs/1611.02731)) with the following characteristics:
#
# *   16-dim latent variables $z$ with a MADE prior, with $\epsilon \sim N(0, I)$
# *   An approximate posterior $q_\theta(z|x) = N(z; \mu_\theta(x), \Sigma_\theta(x))$, where $\mu_\theta(x)$ is the mean vector, and $\Sigma_\theta(x)$ is a diagonal covariance matrix
# *   A decoder $p(x|z) = N(x; \mu_\phi(z), I)$, where $\mu_\phi(z)$ is the mean vector. (We are not learning the covariance of the decoder)
#
# You can use the same encoder / decoder architectures and training hyperparameters as in homework 5. For your MADE prior, it would suffice to use two hidden layers of size $512$. More explicitly, your MADE AF (mapping from $z\rightarrow \epsilon$) should output location $\mu_\psi(z)$ and scale parameters $\sigma_\psi(z)$ and do the following transformation on $z$:
# $$\epsilon = z \odot \sigma_\psi(z) + \mu_\psi(z)$$
#
# where the $i$th element of $\sigma_\psi(z)$ is computed from $z_{<i}$ (same for $\mu_\psi(z)$) and optimize the objective
#
# $$-E_{z\sim q(z|x)}[\log{p(x|z)}] + E_{z\sim q(z|x)}[\log{q(z|x)} - \log{p(z)}]$$
# where $$\log{p(z)} = \log{p(\epsilon)} + \log{\det\left|\frac{d\epsilon}{dz}\right|}$$
#
#
#
#
#
# **You will provide the following deliverables**
#
#
# 1.   Over the course of training, record the average full negative ELBO, reconstruction loss, and KL term of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from your trained VAE
# 4. 50 real-image / reconstruction pairs (for some $x$, encode and then decode)
# 5. Interpolations of length 10 between 10 pairs of test images from your VAE (100 images total)

# %% [markdown]
# ### Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
def q1(train_data, test_data, dset_id):
    """
    train_data: An (n_train, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    test_data: An (n_test, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    dset_id: An identifying number of which dataset is given (1 or 2). Most likely
               used to set different hyperparameters for different datasets

    Returns
    - a (# of training iterations, 3) numpy array of full negative ELBO, reconstruction loss E[-log p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated every minibatch
    - a (# of epochs + 1, 3) numpy array of full negative ELBO, reconstruciton loss E[-p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated once at initialization and after each epoch
    - a (100, 32, 32, 3) numpy array of 100 samples from your VAE with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 50 real image / reconstruction pairs
      FROM THE TEST SET with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 10 interpolations of length 10 between
      pairs of test images. The output should be those 100 images flattened into
      the specified shape with values in {0, ..., 255}
    """
    train_data = 2 * (np.transpose(train_data, (0, 3, 1, 2)) / 255.0).astype('float32') - 1
    test_data = 2 * (np.transpose(test_data, (0, 3, 1, 2)) / 255.0).astype('float32') - 1

    train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True)
    test_dataloader = DataLoader(test_data, batch_size=256)

    vae_trainer = VAETrainer(in_channels=3, latent_dim=16, device=device, use_prior=True, made_hidden_dims=[512, 512])

    train_losses, test_losses = vae_trainer.train(train_dataloader, n_epochs=20, lr=1e-3, test_dataloader=test_dataloader, beta=1.0)
    vae_model = vae_trainer.vae_model

    samples = (vae_trainer.sample(100).detach().cpu().numpy() * 0.5 + 0.5) * 255

    test_images = torch.tensor(test_data[:50], device=device)
    with torch.no_grad():
        test_reconstructed = torch.clip(vae_model(test_images)[0], -1, 1)
    pairs = (torch.vstack((test_images, test_reconstructed)).permute(0, 2, 3, 1).detach().cpu().numpy() * 0.5 + 0.5) * 255

    test_images = torch.tensor(test_data[50:70], device=device)
    with torch.no_grad():
        z = vae_model.reparameterize(*vae_model.encode(test_images))
        z1, z2 = z.chunk(2, dim=0)

        interpolations = torch.vstack([vae_model.decode(z1 * (1 - alpha) + z2 * alpha) for alpha in np.linspace(0, 1, 10)])
        interpolations = torch.clip(interpolations, -1, 1)
        interpolations = (interpolations.permute(0, 2, 3, 1).detach().cpu().numpy() * 0.5 + 0.5) * 255

    return train_losses, test_losses, samples, pairs, interpolations

# %% [markdown]
# ### Results
# Once you've finished `q1`, execute the cells below to visualize and save your results.

# %%
q1_save_results(1, q1)
# Out:
# Training:   0%|          | 0/20 [00:00<?, ?it/s]
# Final -ELBO: 122.8544, Recon Loss: 105.5940, KL Loss: 17.2604

# %%
q1_save_results(2, q1)
# Out:
# Training:   0%|          | 0/20 [00:00<?, ?it/s]
# Final -ELBO: 239.5582, Recon Loss: 210.0745, KL Loss: 29.4836

# %% [markdown]
# # Question 2: VQ-VAE
# In this question, you with train a [VQ-VAE](https://arxiv.org/abs/1711.00937) on the colored shapes dataset and SVHN. If you are confused on how the VQ-VAE works, you may find [Lilian Weng's blogpost](https://lilianweng.github.io/lil-log/2018/08/12/from-autoencoder-to-beta-vae.html#vq-vae-and-vq-vae-2) to be useful.
#
# You may experiment with different hyperparameters and architecture designs, but the following designs for the VQ-VAE architecture may be useful.
#
# ```
# conv2d(in_channels, out_channels, kernel_size, stride, padding)
# transpose_conv2d(in_channels, out_channels, kernel_size, stride, padding)
# linear(in_dim, out_dim)
# batch_norm2d(dim)
#
# residual_block(dim)
#     batch_norm2d(dim)
#     relu()
#     conv2d(dim, dim, 3, 1, 1)
#     batch_norm2d(dim)
#     relu()
#     conv2d(dim, dim, 1, 1, 0)
#
# Encoder
#     conv2d(3, 256, 4, 2, 1) 16 x 16
#     batch_norm2d(256)
#     relu()
#     conv2d(256, 256, 4, 2, 1) 8 x 8
#     residual_block(256)
#     residual_block(256)
#
# Decoder
#     residual_block(256)
#     residual_block(256)
#     batch_norm2d(256)
#     relu()
#     transpose_conv2d(256, 256, 4, 2, 1) 16 x 16
#     batch_norm2d(256)
#     relu()
#     transpose_conv2d(256, 3, 4, 2, 1) 32 x 32
# ```
#
# A few other tips:
# *   Use a codebook with $K = 128$ latents each with a $D = 256$ dimensional embedding vector
# *   You should initialize each element in your $K\times D$ codebook to be uniformly random in $[-1/K, 1/K]$
# *   Use batch size 128 with a learning rate of $10^{-3}$ and an Adam optimizer
# *   Center and scale your images to $[-1, 1]$
# *   Supposing that $z_e(x)$ is the encoder output, and $z_q(x)$ is the quantized output using the codebook, you can implement the straight-through estimator as follows (where below is fed into the decoder):
#   * `(z_q(x) - z_e(x)).detach() + z_e(x)` in Pytorch
#
# In addition to training the VQ-VAE, you will also need to train a PixelCNN prior on the categorical latents in order to sample. For your architecture, you may find the following useful:
# *   Since the input is a 2D grid of discrete values, you should have an input (learned) embedding layer to map the discrete values to embeddings of length $64$
# *   Use a single Type A masked convolutions followed by 10-15 residual blocks (same structure as HW 1), and $2$ $1\times 1$ convolutions of $512$ and $K$ channels respectively.
# *   You may find normalization methods (e.g. BatchNorm, LayerNorm) to be useful
# *   Use batch size 128 with a learning rate of $10^{-3}$ and an Adam optimizer
#
# **You will provide the following deliverables**
#
#
# 1.   Over the course of training, record the average loss of the training data (per minibatch) and test data (for your entire test set) **for both your VQ-VAE and PixelCNN prior**. Code is provided that automatically plots the training curves.
# 2. Report the final test set performances of your final models
# 3. 100 samples from your trained VQ-VAE and PixelCNN prior
# 4. 50 real-image / reconstruction pairs (for some $x$, encode and then decode)

# %% [markdown]
# ## Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
@torch.no_grad()
def dataset_to_code(vqvae, dataloader, device):
    prior_data = []
    for batch in dataloader:
        batch = batch.to(device)
        code = vqvae.encode_to_code(batch).squeeze(1)
        prior_data.append(code.long())
    return torch.cat(prior_data, dim=0)


def q2(train_data, test_data, dset_id):
    """
    train_data: An (n_train, 32, 32, 3) uint8 numpy array of color images with values in [0, 255]
    test_data: An (n_test, 32, 32, 3) uint8 numpy array of color images with values in [0, 255]
    dset_id: An identifying number of which dataset is given (1 or 2). Most likely
               used to set different hyperparameters for different datasets

    Returns
    - a (# of training iterations,) numpy array of VQ-VAE train losess evaluated every minibatch
    - a (# of epochs + 1,) numpy array of VQ-VAE train losses evaluated once at initialization and after each epoch
    - a (# of training iterations,) numpy array of PixelCNN prior train losess evaluated every minibatch
    - a (# of epochs + 1,) numpy array of PixelCNN prior train losses evaluated once at initialization and after each epoch
    - a (100, 32, 32, 3) numpy array of 100 samples with values in {0, ... 255}
    - a (100, 32, 32, 3) numpy array of 50 real image / reconstruction pairs
      FROM THE TEST SET with values in [0, 255]
    """

    train_data = 2 * (np.transpose(train_data, (0, 3, 1, 2)) / 255.0).astype('float32') - 1
    test_data = 2 * (np.transpose(test_data, (0, 3, 1, 2)) / 255.0).astype('float32') - 1

    train_dataloader = DataLoader(train_data[:10], batch_size=2, shuffle=True)
    test_dataloader = DataLoader(test_data[:10], batch_size=2)

    vq_vae_trainer = VqVaeTrainer(3, 256, 128, 256, device=device)
    train_losses, test_losses = vq_vae_trainer.train(train_dataloader, 1, 1e-3, test_dataloader)

    vq_vae = vq_vae_trainer.vq_vae
    vq_vae.eval()

    pixel_cnn = PixelCNNVae(in_size=8, in_channels=64, num_bins=128, num_blocks=1)
    train_code_dataloader = DataLoader(dataset_to_code(vq_vae, train_dataloader, device), batch_size=128, shuffle=True)
    test_code_dataloader = DataLoader(dataset_to_code(vq_vae, test_dataloader, device), batch_size=128)

    pixel_train_losses, pixel_test_losses =\
        train_pixel_cnn(pixel_cnn, train_code_dataloader, test_code_dataloader, device, epochs=1, lr=1e-3)

    pixel_cnn.eval()

    samples = pixel_cnn.sample(num_samples=100, device=device)
    samples = (torch.clip(vq_vae.decode_from_code(samples.unsqueeze(1)), -1, 1) * 0.5 + 0.5) * 255.
    samples = samples.cpu().numpy().transpose(0, 2, 3, 1)

    batch = torch.tensor(test_data[:50], device=device)
    with torch.no_grad():
        reconstructed, _, _ = vq_vae(batch)
        reconstructed = torch.clip(reconstructed, -1, 1)

    result = (torch.vstack((batch, reconstructed)).cpu().numpy().transpose(0, 2, 3, 1) * 0.5 + 0.5) * 255
    return train_losses, test_losses, pixel_train_losses, pixel_test_losses, samples, result

# %% [markdown]
# ## Results
# Once you've finished `q2`, execute the cells below to visualize and save your results.

# %%
q2_save_results(1, q2)
# Out:
# Training: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s, test_loss=1.63, train_loss=22.5]
# PixelCNN training: 100%|██████████| 1/1 [00:00<00:00, 23.00it/s, test_loss=4.63, train_loss=4.83]
# VQ-VAE Final Test Loss: 1.6329
# PixelCNN Prior Final Test Loss: 4.6252

# %%
q2_save_results(2, q2)

# %% [markdown]
# # Bonus 4

# %% [markdown]
# ## Part (a) Improving VQ-VAE Results
# Improve upon your results in Q2, one option being trying to implement or train a stronger autoregressive model such as a Gated PixelCNN.

# %% [markdown]
# ### Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
def b4_a(train_data, test_data, dset_id):
    """
    train_data: An (n_train, 32, 32, 3) uint8 numpy array of color images with values in [0, 255]
    test_data: An (n_test, 32, 32, 3) uint8 numpy array of color images with values in [0, 255]
    dset_id: An identifying number of which dataset is given (1 or 2). Most likely
               used to set different hyperparameters for different datasets

    Returns
    - a (# of training iterations,) numpy array of VQ-VAE train losess evaluated every minibatch
    - a (# of epochs + 1,) numpy array of VQ-VAE train losses evaluated once at initialization and after each epoch
    - a (# of training iterations,) numpy array of PixelCNN prior train losess evaluated every minibatch
    - a (# of epochs + 1,) numpy array of PixelCNN prior train losses evaluated once at initialization and after each epoch
    - a (100, 32, 32, 3) numpy array of 100 samples with values in {0, ... 255}
    - a (100, 32, 32, 3) numpy array of 50 real image / reconstruction pairs
      FROM THE TEST SET with values in [0, 255]
    """

    """ YOUR CODE HERE """

# %% [markdown]
# ### Results
# Once you've finished `b4_a`, execute the cells below to visualize and save your results.

# %%
b4_a_save_results(2, b4_a)

# %% [markdown]
# ## Part (b) PixelVAE
# Implement and train a VAE with a PixelCNN decoder, and get it to produce good samples but not ignore latents. It may help to reference the latent variable model slides on techniques to prevent posterior collapse.

# %% [markdown]
# ### Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
def b4_b(train_data, test_data):
    """
    train_data: An (n_train, 28, 28, 1) uint8 numpy array of MNIST binary images
    test_data: An (n_test, 28, 28, 1) uint8 numpy array of MNIST binary images

    Returns
    - a (# of training iterations, 3) numpy array of full negative ELBO, reconstruction loss E[-log p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated every minibatch
    - a (# of epochs + 1, 3) numpy array of full negative ELBO, reconstruciton loss E[-p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated once at initialization and after each epoch
    - a (100, 28, 28, 1) numpy array of 100 samples with values in {0, 1}
    - a (100, 28, 28, 1) numpy array of 50 real-image / reconstruction pairs with values in {0, 1}
    """

    """ YOUR CODE HERE """

# %% [markdown]
# ### Results
# Once you've finished `b4_b`, execute the cells below to visualize and save your results

# %%
b4_b_save_results(b4_b)
